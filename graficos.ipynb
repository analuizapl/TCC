# %%
import matplotlib.pyplot as plt
import numpy as np
bases = ['Splice','Presos ','Mushrooms ','Depressão ','TDAH ','Sonar ','Spambase ','Student ','Tokyo ','Biodeg ','Churn ','Horse colic ','Ionosphere ','Phishing websites Data ','Breast Cancer Wisconsin ','Smoking ','Default of credit card clients ','Home Equity ','Seismic ','KC2 ','German credit ','Price ','Twonorm ','Australian ','Lung Cancer ','Eye State Classification EEG ','Heart Attack ','Heart Failure\\ Prediction ','Brain Stroke ','Indian Liver Patient ','Magic ','Breast Cancer Coimbra ','Compass ','Diabetes ','Employee Future ','Titanic ','Monk ','Liver disorders (BUPA) ','Vertebral Column ','Mammographic masses ','Room Occupancy ','Banknote ','Phoneme ','Haberman ','Banana']
tempo = [0.002832395,0.003680128,0.001859937,0.005398933,0.003249048,0.001736172,0,0.000713309,0,0.065875,0,0,0.00093943,0.000756599,0,0.001164161,0.012676907,0.005952923,0.001621752,0.018514941,0.000733585,0.00067259,0,0.132567,0.001287311,0.101116463,0.000865532,0.00054067,8.176254,0.002464926,0,0,0.000656383,0.001318563,0.000614875,0.002254685,0,0.001381419,0,0.000709595,0.000948712,0,0,0.000566652,0.000671267]
l1=[0,4,8]

plt.scatter( tempo,  bases, alpha=0.5)
plt.gcf().set_size_inches((10, 10))  
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
bases = ['Splice','Presos ','Mushrooms ','Depressão ','TDAH ','Sonar ','Spambase ','Student ','Tokyo ','Biodeg ','Churn ','Horse colic ','Ionosphere ','Phishing websites Data ','Breast Cancer Wisconsin ','Smoking ','Default of credit card clients ','Home Equity ','Seismic ','KC2 ','German credit ','Price ','Twonorm ','Australian ','Lung Cancer ','Eye State Classification EEG ','Heart Attack ','Heart Failure\\ Prediction ','Brain Stroke ','Indian Liver Patient ','Magic ','Breast Cancer Coimbra ','Compass ','Diabetes ','Employee Future ','Titanic ','Monk ','Liver disorders (BUPA) ','Vertebral Column ','Mammographic masses ','Room Occupancy ','Banknote ','Phoneme ','Haberman ','Banana']
tempoAg = [0.004021175 ,0.003311623 ,0.002277357 ,0.002864888 ,0 ,0 ,0 ,0.001102482 ,0.0013058730000000001 ,0.003485187 ,0 ,0 ,0.001139153 ,0 ,0.00094791 ,0.003363844 ,0.0022848119999999998 ,0.0012029350000000002 ,0.0009993930000000001 ,0.001040378 ,0.0009536700000000001 ,0.0009404970000000001 ,0.001088346 ,0.000881154 ,0.039106482 ,0.001017081 ,0.0009014590000000001 ,0.002514777 ,0.000941406 ,0 ,0 ,0.004194326 ,0.019410049 ,0.000659625 ,0.0007191509999999999 ,0.001847254 ,0 ,0.006465542 ,0.004164304999999999 ,0.004191049999999999 ,0.0008324970000000001 ,0.000718618 ,0 ,0.004573187 ,0.004835873]
plt.scatter( tempoAg,  bases, alpha=0.5)
plt.gcf().set_size_inches((10, 10))  
plt.show()

# %%
import matplotlib.pyplot as plt
bases = ['Splice','Presos ','Mushrooms ','Depressão ','TDAH ','Sonar ','Spambase ','Student ','Tokyo ','Biodeg ','Churn ','Horse colic ','Ionosphere ','Phishing websites\\ Data ','Breast Cancer Wisconsin ','Smoking ','Default of credit\\ card clients ','Home Equity ','Seismic ','KC2 ','German credit ','Price ','Twonorm ','Australian ','Lung Cancer ','Eye State Classification EEG ','Heart Attack ','Heart Failure\\ Prediction ','Brain Stroke ','Indian Liver Patient ','Magic ','Breast Cancer Coimbra ','Compass ','Diabetes ','Employee Future ','Titanic ','Monk ','Liver disorders\\ (BUPA) ','Vertebral Column ','Mammographic masses ','Room Occupancy ','Banknote ','Phoneme ','Haberman ','Banana']
atributosTotal = [181,130,113,87,63,61,58,44,44,42,41,41,35,32,30,27,25,24,23,22,21,21,21,16,16,15,14,13,11,11,11,10,10,9,9,9,8,7,7,6,6,5,5,4,3]
trocasAA = [10.5,6.6,9.8,2.7,15,12.6,0,2.6,0,3,0,0,2.5,2.1,0,2.5,2.9,5.3,7,6.5,3.2,3.8,0,3,6.8,2.9,6.8,2.4,1.7,2.6,0,0,2.8,2.8,1.7,2.7,0,2.8,0,2.7,2.5,0,0,2.3,2]
trocasAG = [31.9,34.1,11.5,40.8,0,0,0,13.3,37,21.2,0,0,31.6,0,4.9,18.3,18.1,18.4,5.3,16.6,9.7,15.1,21,10,5.8,15,8.3,9,5,0,0,4.4,3.5,7.7,3.3,9.9,0,6.6,7,2.6,4.2,4.7,0,2.8,2.7]
plt.scatter(atributosTotal, bases, alpha=0.7,label = "Quantidade de atributos")
plt.scatter(trocasAA, bases, alpha=0.7,label = "Média de trocas (Amostragem aleatória)", color='green')
plt.scatter(trocasAG, bases, alpha=0.7,label = "Média de trocas (AG)", color='red')
plt.legend(loc="upper right")
plt.gcf().set_size_inches((10, 10))  
plt.show()

# %%
import matplotlib.pyplot as plt
bases = ['Splice','Presos ','Mushrooms ','Depressão ','TDAH ','Sonar ','Spambase ','Student ','Tokyo ','Biodeg ','Churn ','Horse colic ','Ionosphere ','Phishing websites\\ Data ','Breast Cancer Wisconsin ','Smoking ','Default of credit\\ card clients ','Home Equity ','Seismic ','KC2 ','German credit ','Price ','Twonorm ','Australian ','Lung Cancer ','Eye State Classification EEG ','Heart Attack ','Heart Failure\\ Prediction ','Brain Stroke ','Indian Liver Patient ','Magic ','Breast Cancer Coimbra ','Compass ','Diabetes ','Employee Future ','Titanic ','Monk ','Liver disorders\\ (BUPA) ','Vertebral Column ','Mammographic masses ','Room Occupancy ','Banknote ','Phoneme ','Haberman ','Banana']

desempenhoAOC = [10.5,6.6,9.8,2.7,15,12.6,0,2.6,0,3,0,0,2.5,2.1,0,2.5,2.9,5.3,7,6.5,3.2,3.8,0,3,6.8,2.9,6.8,2.4,1.7,2.6,0,0,2.8,2.8,1.7,2.7,0,2.8,0,2.7,2.5,0,0,2.3,2]
desempenhoAOC2 = [31.9,34.1,11.5,40.8,0,0,0,13.3,37,21.2,0,0,31.6,0,4.9,18.3,18.1,18.4,5.3,16.6,9.7,15.1,21,10,5.8,15,8.3,9,5,0,0,4.4,3.5,7.7,3.3,9.9,0,6.6,7,2.6,4.2,4.7,0,2.8,2.7]

plt.scatter(desempenhoAOC, bases, alpha=0.7,label = "Média de trocas (Amostragem aleatória)", color='green')
plt.scatter(desempenhoAOC2, bases, alpha=0.7,label = "Média de trocas (AG)", color='red')
plt.legend(loc="upper right")
plt.gcf().set_size_inches((10, 10))  
plt.show()
